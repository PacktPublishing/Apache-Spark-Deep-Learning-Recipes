# %%
spark = SparkSession.builder \
    .master("local") \
    .appName("StockMarket") \
    .config("spark.executor.memory", "6gb") \
    .getOrCreate()

# %%
df =spark.read.format('com.databricks.spark.csv')\
                    .options(header='true', inferschema='true')\
                    .load('AAPL.csv')

# %%
df.show()
# Out:
# +-------------------+--------+--------+--------+--------+---------+---------+
# |               Date|    Open|    High|     Low|   Close|Adj Close|   Volume|
# +-------------------+--------+--------+--------+--------+---------+---------+
# |1999-12-31 00:00:00|3.604911|3.674107|3.553571|3.671875| 2.467498| 40952800|
# |2000-01-03 00:00:00|3.745536|4.017857|3.631696|3.997768| 2.686497|133949200|
# |2000-01-04 00:00:00|3.866071|3.950893|3.613839|3.660714| 2.459998|128094400|
# |2000-01-05 00:00:00|3.705357|3.948661|3.678571|3.714286| 2.495997|194580400|
# |2000-01-06 00:00:00|3.790179|3.821429|3.392857|3.392857| 2.279998|191993200|
# |2000-01-07 00:00:00|3.446429|3.607143|3.410714|3.553571| 2.387998|115183600|
# |2000-01-10 00:00:00|3.642857|3.651786|3.383929|3.491071| 2.345998|126266000|
# |2000-01-11 00:00:00|3.426339|3.549107|3.232143|  3.3125| 2.225998|110387200|
# |2000-01-12 00:00:00|3.392857|3.410714|3.089286|3.113839| 2.092498|244017200|
# |2000-01-13 00:00:00|3.374439|3.526786|3.303571|3.455357| 2.321998|258171200|
# |2000-01-14 00:00:00|3.571429|3.651786|3.549107|3.587054| 2.410497| 97594000|
# |2000-01-18 00:00:00|3.607143|3.785714|3.587054|3.712054| 2.494497|114794400|
# |2000-01-19 00:00:00|3.772321|3.883929|3.691964|3.805804| 2.557498|149410800|
# |2000-01-20 00:00:00|   4.125|4.339286|4.053571|4.053571| 2.723998|457783200|
# |2000-01-21 00:00:00|4.080357|4.080357|3.935268|3.975446| 2.671498|123981200|
# |2000-01-24 00:00:00|3.872768|4.026786|3.754464|3.794643| 2.549998|110219200|
# |2000-01-25 00:00:00|    3.75|4.040179| 3.65625|4.008929| 2.693998|124286400|
# |2000-01-26 00:00:00|3.928571|4.078125|3.919643|3.935268| 2.644498| 91789600|
# |2000-01-27 00:00:00|3.886161|4.035714|3.821429|3.928571| 2.639997| 85036000|
# |2000-01-28 00:00:00|3.863839|3.959821| 3.59375|3.629464| 2.438998|105837200|
# +-------------------+--------+--------+--------+--------+---------+---------+
# only showing top 20 rows

# %%
import pyspark.sql.functions as f
df = df.withColumn('date', f.to_date('Date'))

# %%
df.show(n=5)
# Out:
# +----------+--------+--------+--------+--------+---------+---------+
# |      date|    Open|    High|     Low|   Close|Adj Close|   Volume|
# +----------+--------+--------+--------+--------+---------+---------+
# |1999-12-31|3.604911|3.674107|3.553571|3.671875| 2.467498| 40952800|
# |2000-01-03|3.745536|4.017857|3.631696|3.997768| 2.686497|133949200|
# |2000-01-04|3.866071|3.950893|3.613839|3.660714| 2.459998|128094400|
# |2000-01-05|3.705357|3.948661|3.678571|3.714286| 2.495997|194580400|
# |2000-01-06|3.790179|3.821429|3.392857|3.392857| 2.279998|191993200|
# +----------+--------+--------+--------+--------+---------+---------+
# only showing top 5 rows

# %%
date_breakdown = ['year', 'month', 'day']
for i in enumerate(date_breakdown):
    index = i[0]
    name = i[1]
    df = df.withColumn(name, f.split('date', '-')[index])

df.show(n=10)
# Out:
# +----------+--------+--------+--------+--------+---------+---------+----+-----+---+
# |      date|    Open|    High|     Low|   Close|Adj Close|   Volume|year|month|day|
# +----------+--------+--------+--------+--------+---------+---------+----+-----+---+
# |1999-12-31|3.604911|3.674107|3.553571|3.671875| 2.467498| 40952800|1999|   12| 31|
# |2000-01-03|3.745536|4.017857|3.631696|3.997768| 2.686497|133949200|2000|   01| 03|
# |2000-01-04|3.866071|3.950893|3.613839|3.660714| 2.459998|128094400|2000|   01| 04|
# |2000-01-05|3.705357|3.948661|3.678571|3.714286| 2.495997|194580400|2000|   01| 05|
# |2000-01-06|3.790179|3.821429|3.392857|3.392857| 2.279998|191993200|2000|   01| 06|
# |2000-01-07|3.446429|3.607143|3.410714|3.553571| 2.387998|115183600|2000|   01| 07|
# |2000-01-10|3.642857|3.651786|3.383929|3.491071| 2.345998|126266000|2000|   01| 10|
# |2000-01-11|3.426339|3.549107|3.232143|  3.3125| 2.225998|110387200|2000|   01| 11|
# |2000-01-12|3.392857|3.410714|3.089286|3.113839| 2.092498|244017200|2000|   01| 12|
# |2000-01-13|3.374439|3.526786|3.303571|3.455357| 2.321998|258171200|2000|   01| 13|
# +----------+--------+--------+--------+--------+---------+---------+----+-----+---+
# only showing top 10 rows

# %%
df_plot = df.select('year', 'Adj Close').toPandas()

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
df_plot.set_index('year', inplace=True)
df_plot.plot(figsize=(16, 6), grid=True)
plt.title('Apple stock')
plt.ylabel('Stock Quote ($)')
plt.show()

# %%
df.toPandas().shape
# Out:
# (4610, 10)

# %%
df.dropna().count()
# Out:
# 4610

# %%
df.select('Open', 'High', 'Low', 'Close', 'Adj Close').describe().show()
# Out:
# +-------+-----------------+------------------+------------------+------------------+-----------------+
# |summary|             Open|              High|               Low|             Close|        Adj Close|
# +-------+-----------------+------------------+------------------+------------------+-----------------+
# |  count|             4610|              4610|              4610|              4610|             4610|
# |   mean|46.28525130086777|46.717162366811266|45.819553227982546|46.277442902819914|39.77304221626904|
# | stddev|49.17699648166954| 49.55366398613007| 48.78861283288266|   49.176513212795|47.59403758365483|
# |    min|         0.927857|          0.942143|          0.908571|          0.937143|         0.629759|
# |    max|       182.589996|             183.5|        180.210007|        181.720001|       180.389313|
# +-------+-----------------+------------------+------------------+------------------+-----------------+

# %%
df.groupBy(['year']).agg({'Adj Close':'count'})\
    .withColumnRenamed('count(Adj Close)', 'Row Count')\
    .orderBy(["year"],ascending=False)\
    .show()
# Out:
# +----+---------+
# |year|Row Count|
# +----+---------+
# |2018|       81|
# |2017|      251|
# |2016|      252|
# |2015|      252|
# |2014|      252|
# |2013|      252|
# |2012|      250|
# |2011|      252|
# |2010|      252|
# |2009|      252|
# |2008|      253|
# |2007|      251|
# |2006|      251|
# |2005|      252|
# |2004|      252|
# |2003|      252|
# |2002|      252|
# |2001|      248|
# |2000|      252|
# |1999|        1|
# +----+---------+

# %%
trainDF = df[df.year < 2017]
testDF = df[df.year > 2016]

# %%
trainDF.toPandas().shape
# Out:
# (4278, 10)

# %%
testDF.toPandas().shape
# Out:
# (332, 10)

# %%
trainDF_plot = trainDF.select('year', 'Adj Close').toPandas()
trainDF_plot.set_index('year', inplace=True)
trainDF_plot.plot(figsize=(16, 6), grid=True)
plt.title('Apple Stock 2000-2016')
plt.ylabel('Stock Quote ($)')
plt.show()

# %%
testDF_plot = testDF.select('year', 'Adj Close').toPandas()
testDF_plot.set_index('year', inplace=True)
testDF_plot.plot(figsize=(16, 6), grid=True)
plt.title('Apple Stock 2017-2018')
plt.ylabel('Stock Quote ($)')
plt.show()

# %%
import numpy as np
trainArray=np.array(trainDF.select('Open','High','Low','Close','Volume','Adj Close').collect())
testArray=np.array(testDF.select('Open','High','Low','Close','Volume','Adj Close').collect())

# %%
print(trainArray[0])
print('---------------')
print(testArray[0])
# Out:
# [3.604911e+00 3.674107e+00 3.553571e+00 3.671875e+00 4.095280e+07
#  2.467498e+00]
# ---------------
# [1.15800003e+02 1.16330002e+02 1.14760002e+02 1.16150002e+02
#  2.87819000e+07 1.13013916e+02]

# %%
from sklearn.preprocessing import MinMaxScaler
minMaxScale = MinMaxScaler()

# %%
minMaxScale.fit(trainArray)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
testingArray = minMaxScale.transform(testArray)
trainingArray = minMaxScale.transform(trainArray)

# %%
print(testingArray[0])
print('---------------')
print(trainingArray[0])
# Out:
# [0.86025834 0.86369548 0.8724821  0.87240926 0.01026612 0.90325671]
# ---------------
# [0.02004801 0.02044916 0.02026953 0.02070781 0.01686076 0.01477032]

# %%
xtrain = trainingArray[:, 0:-1]
xtest = testingArray[:, 0:-1]
ytrain = trainingArray[:, -1:]
ytest = testingArray[:, -1:]

# %%
trainingArray[0]
# Out:
# array([0.02004801, 0.02044916, 0.02026953, 0.02070781, 0.01686076,
#        0.01477032])

# %%
xtrain[0]
# Out:
# array([0.02004801, 0.02044916, 0.02026953, 0.02070781, 0.01686076])

# %%
ytrain[0]
# Out:
# array([0.01477032])

# %%
print('xtrain shape = {}'.format(xtrain.shape))
print('xtest shape = {}'.format(xtest.shape))
print('ytrain shape = {}'.format(ytrain.shape))
print('ytest shape = {}'.format(ytest.shape))
# Out:
# xtrain shape = (4278, 5)
# xtest shape = (332, 5)
# ytrain shape = (4278, 1)
# ytest shape = (332, 1)

# %%
plt.figure(figsize=(16,6))
plt.plot(xtrain[:,0],color='red', label='open')
plt.plot(xtrain[:,1],color='blue', label='high')
plt.plot(xtrain[:,2],color='green', label='low')
plt.plot(xtrain[:,3],color='purple', label='close')
plt.legend(loc = 'upper left')
plt.title('Open, High, Low, and Close by Day')
plt.xlabel('Days')
plt.ylabel('Scaled Quotes')
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.plot(xtrain[:,4],color='black', label='volume')
plt.legend(loc = 'upper right')
plt.title('Volume by Day')
plt.xlabel('Days')
plt.ylabel('Scaled Volume')
plt.show()

# %%
from keras import models, layers
# Out:
# /home/test/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model = models.Sequential()
model.add(layers.LSTM(1, input_shape=(1,5)))
model.add(layers.Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
xtrain = xtrain.reshape((xtrain.shape[0], 1, xtrain.shape[1]))
xtest = xtest.reshape((xtest.shape[0], 1, xtest.shape[1]))

# %%
print('The shape of xtrain is {}: '.format(xtrain.shape))
print('The shape of xtest is {}: '.format(xtest.shape))
# Out:
# The shape of xtrain is (4278, 1, 5):
# The shape of xtest is (332, 1, 5):

# %%
loss = model.fit(xtrain, ytrain, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 4278/4278 [==============================] - 6s 1ms/step - loss: 0.0632
# Epoch 2/100
# 4278/4278 [==============================] - 4s 998us/step - loss: 0.0098
# Epoch 3/100
# 4278/4278 [==============================] - 4s 949us/step - loss: 0.0029
# Epoch 4/100
# 4278/4278 [==============================] - 4s 943us/step - loss: 0.0020
# Epoch 5/100
# 4278/4278 [==============================] - 4s 830us/step - loss: 0.0017
# Epoch 6/100
# 4278/4278 [==============================] - 4s 921us/step - loss: 0.0015
# Epoch 7/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 0.0014
# Epoch 8/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 0.0013
# Epoch 9/100
# 4278/4278 [==============================] - 4s 976us/step - loss: 0.0013
# Epoch 10/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 0.0012
# Epoch 11/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 0.0012
# Epoch 12/100
# 4278/4278 [==============================] - 4s 1ms/step - loss: 0.0011
# Epoch 13/100
# 4278/4278 [==============================] - 4s 1ms/step - loss: 0.0011
# Epoch 14/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 0.0011
# Epoch 15/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 0.0011
# Epoch 16/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 0.0010
# Epoch 17/100
# 4278/4278 [==============================] - 4s 820us/step - loss: 0.0010
# Epoch 18/100
# 4278/4278 [==============================] - 4s 848us/step - loss: 9.8712e-04 0s - loss: 9.9237
# Epoch 19/100
# 4278/4278 [==============================] - 4s 851us/step - loss: 9.5371e-04
# Epoch 20/100
# 4278/4278 [==============================] - 4s 985us/step - loss: 9.4101e-04
# Epoch 21/100
# 4278/4278 [==============================] - 6s 1ms/step - loss: 9.2910e-04
# Epoch 22/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 9.0265e-04
# Epoch 23/100
# 4278/4278 [==============================] - 6s 1ms/step - loss: 8.9833e-04
# Epoch 24/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 8.8884e-04
# Epoch 25/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 8.7070e-04
# Epoch 26/100
# 4278/4278 [==============================] - 6s 1ms/step - loss: 8.6174e-04
# Epoch 27/100
# 4278/4278 [==============================] - 4s 919us/step - loss: 8.5421e-04
# Epoch 28/100
# 4278/4278 [==============================] - 6s 1ms/step - loss: 8.4689e-04
# Epoch 29/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 8.4758e-04
# Epoch 30/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 8.2231e-04
# Epoch 31/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 8.2198e-04
# Epoch 32/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 8.1659e-04
# Epoch 33/100
# 4278/4278 [==============================] - 6s 1ms/step - loss: 8.1412e-04
# Epoch 34/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 8.0046e-04
# Epoch 35/100
# 4278/4278 [==============================] - 6s 1ms/step - loss: 7.9925e-04
# Epoch 36/100
# 4278/4278 [==============================] - 6s 2ms/step - loss: 7.9013e-04A: 0s -
# Epoch 37/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 7.8703e-04
# Epoch 38/100
# 4278/4278 [==============================] - 6s 1ms/step - loss: 7.7785e-04
# Epoch 39/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 7.8516e-04
# Epoch 40/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 7.7498e-04
# Epoch 41/100
# 4278/4278 [==============================] - 4s 1ms/step - loss: 7.6904e-04
# Epoch 42/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 7.6806e-04
# Epoch 43/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 7.7537e-04
# Epoch 44/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 7.6440e-04
# Epoch 45/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 7.6167e-04A: 0s - l
# Epoch 46/100
# 4278/4278 [==============================] - 4s 1ms/step - loss: 7.5724e-04
# Epoch 47/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 7.5414e-04
# Epoch 48/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 7.5672e-04
# Epoch 49/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 7.5766e-04
# Epoch 50/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 7.4664e-04
# Epoch 51/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 7.4532e-04
# Epoch 52/100
# 4278/4278 [==============================] - 5s 1ms/step - loss: 7.4869e-04
# Epoch 53/100
# 4278/4278 [==============================] - 4s 856us/step - loss: 7.4209e-04
# Epoch 54/100
# 4278/4278 [==============================] - 4s 954us/step - loss: 7.4477e-04
# Epoch 55/100
# 4278/4278 [==============================] - 4s 878us/step - loss: 7.4190e-04
# Epoch 56/100
# 4278/4278 [==============================] - 4s 875us/step - loss: 7.3679e-04
# Epoch 57/100
# 4278/4278 [==============================] - 4s 901us/step - loss: 7.3480e-04
# Epoch 58/100
# 4278/4278 [==============================] - 4s 916us/step - loss: 7.3848e-04
# Epoch 59/100
# 4278/4278 [==============================] - 3s 800us/step - loss: 7.3263e-04
# Epoch 60/100
# 4278/4278 [==============================] - 3s 679us/step - loss: 7.3442e-04
# Epoch 61/100
# 4278/4278 [==============================] - 3s 740us/step - loss: 7.2782e-04
# Epoch 62/100
# 4278/4278 [==============================] - 4s 831us/step - loss: 7.3438e-04
# Epoch 63/100
# 4278/4278 [==============================] - ETA: 0s - loss: 7.3511e-0 - 4s 844us/step - loss: 7.3179e-04
# Epoch 64/100
# 4278/4278 [==============================] - 4s 820us/step - loss: 7.2503e-04
# Epoch 65/100
# 4278/4278 [==============================] - 3s 625us/step - loss: 7.2942e-04
# Epoch 66/100
# 4278/4278 [==============================] - 3s 802us/step - loss: 7.2484e-04
# Epoch 67/100
# 4278/4278 [==============================] - 4s 846us/step - loss: 7.2213e-04
# Epoch 68/100
# 4278/4278 [==============================] - 4s 823us/step - loss: 7.1913e-04
# Epoch 69/100
# 4278/4278 [==============================] - 4s 839us/step - loss: 7.2103e-04
# Epoch 70/100
# 4278/4278 [==============================] - 2s 505us/step - loss: 7.0626e-04
# Epoch 71/100
# 4278/4278 [==============================] - 3s 596us/step - loss: 7.2529e-04
# Epoch 72/100
# 4278/4278 [==============================] - 2s 562us/step - loss: 7.2606e-04
# Epoch 73/100
# 4278/4278 [==============================] - 4s 823us/step - loss: 7.0513e-04
# Epoch 74/100
# 4278/4278 [==============================] - 3s 735us/step - loss: 7.0903e-04
# Epoch 75/100
# 4278/4278 [==============================] - 3s 754us/step - loss: 7.1357e-04
# Epoch 76/100
# 4278/4278 [==============================] - 3s 763us/step - loss: 7.1118e-04
# Epoch 77/100
# 4278/4278 [==============================] - 4s 824us/step - loss: 7.1926e-04
# Epoch 78/100
# 4278/4278 [==============================] - 3s 792us/step - loss: 7.0838e-04
# Epoch 79/100
# 4278/4278 [==============================] - 3s 765us/step - loss: 7.0952e-04
# Epoch 80/100
# 4278/4278 [==============================] - 4s 837us/step - loss: 7.0956e-04
# Epoch 81/100
# 4278/4278 [==============================] - 3s 767us/step - loss: 7.1017e-04
# Epoch 82/100
# 4278/4278 [==============================] - 3s 811us/step - loss: 7.0891e-04
# Epoch 83/100
# 4278/4278 [==============================] - 4s 864us/step - loss: 7.1062e-04
# Epoch 84/100
# 4278/4278 [==============================] - 3s 790us/step - loss: 6.9961e-04
# Epoch 85/100
# 4278/4278 [==============================] - 4s 827us/step - loss: 7.0460e-04
# Epoch 86/100
# 4278/4278 [==============================] - 3s 726us/step - loss: 7.0470e-04
# Epoch 87/100
# 4278/4278 [==============================] - 3s 773us/step - loss: 7.0373e-04
# Epoch 88/100
# 4278/4278 [==============================] - 4s 841us/step - loss: 7.0602e-04
# Epoch 89/100
# 4278/4278 [==============================] - 4s 819us/step - loss: 6.9666e-04
# Epoch 90/100
# 4278/4278 [==============================] - 3s 791us/step - loss: 7.0410e-04
# Epoch 91/100
# 4278/4278 [==============================] - 3s 681us/step - loss: 7.0177e-04
# Epoch 92/100
# 4278/4278 [==============================] - 3s 607us/step - loss: 7.0028e-04
# Epoch 93/100
# 4278/4278 [==============================] - 3s 610us/step - loss: 7.0112e-04
# Epoch 94/100
# 4278/4278 [==============================] - 3s 606us/step - loss: 6.9727e-04
# Epoch 95/100
# 4278/4278 [==============================] - 3s 650us/step - loss: 6.9608e-04
# Epoch 96/100
# 4278/4278 [==============================] - 3s 763us/step - loss: 6.9640e-04
# Epoch 97/100
# 4278/4278 [==============================] - 3s 814us/step - loss: 7.0791e-04
# Epoch 98/100
# 4278/4278 [==============================] - 3s 739us/step - loss: 6.9894e-04
# Epoch 99/100
# 4278/4278 [==============================] - 3s 731us/step - loss: 6.9960e-04
# Epoch 100/100
# 4278/4278 [==============================] - 3s 814us/step - loss: 6.9327e-04

# %%
plt.plot(loss.history['loss'], label = 'loss')
plt.title('mean squared error by epoch')
plt.legend()
plt.show()

# %%
predicted = model.predict(xtest)

# %%
combined_array = np.concatenate((ytest, predicted), axis = 1)

# %%
plt.figure(figsize=(16,6))
plt.plot(combined_array[:,0],color='red', label='actual')
plt.plot(combined_array[:,1],color='blue', label='predicted')
plt.legend(loc = 'lower right')
plt.title('2017 Actual vs. Predicted APPL Stock')
plt.xlabel('Days')
plt.ylabel('Scaled Quotes')
plt.show()

# %%
import sklearn.metrics as metrics
np.sqrt(metrics.mean_squared_error(ytest,predicted))
# Out:
# 0.09259977440780147
